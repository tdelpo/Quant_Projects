# %% [markdown]
# **Q1.1** - Explain carefully the difference between selling a call option and buying a put option.

# %% [markdown]
# Answer:
#  - A call option is the right, but not obligation, to buy the underlying at an certain price (strike) by a certain date (expiry/maturity). If you sell a call option, you are selling to another party, the right to buy. As the seller, you will be obligated, if exercised, to sell the underlying to the other party at the agreed price.
#  - The payoff from selling a call option is: \
#         $Payoff = -max(0, Spot(S) - Strike(K)) = min(Strike - Spot, 0)$
#  - A put option is the right, but not obligation, to sell the underlying at a certain price (strike) by a certain date (expiry/maturity). If you buy a put options, you are purchasing the right to sell. The selling of the option is obligated to buy your underlying if exercised.
#  - The payoff from buying a put option is: \
#         $Payoff = max(0, Strike - Spot)$

# %% [markdown]
# **Q1.2** - An investor enters into a short forward contract to sell £100,000 GBP for USD at an exchange rate of 1.3000 USD per pound. How much does the investor gain or lose if the exchange rate at the end of the contract is (a) 1.2900 and (b) 1.3200?

# %% [markdown]
# Answer:
#  - a) The investor has agreed to sell £100,000 for $130,000. If spot exchange is 1.2900, the contract value is ($129,000 - $130,000) = -$1,000
#  - b) The investor has agreed to sell £100,000 for $130,000. If spot exchange is 1.3200, the contract value is ($132,000 - $130,000) = $2,000

# %% [markdown]
# **Q1.3** - A trader enters into a short cotton futures contract when the futures price is 50 cents per pound. The contract is for the delivery of 50,000 pounds. How much does the trader gain or lose if the cotton price at the end of the contract is (a) 48.20 cents per pount and (b) 51.30 cents per pound?

# %% [markdown]
# Answer:
#  - 50,000 pounds at $0.5000/lb = $25,000.
#  - a) 50,000 pounds at $0.4820/lb = $24,100. Payoff = $24,100 - $25,000 = -$900.00
#  - b) 50,000 pounds at $0.5130/lb = $25,650. Payoff = $25,650 - $25,000 = $650.00

# %% [markdown]
# **Q1.4** - Suppose that you write a put contract with a strike price of $40 and an expiration date in 3 months. The current sock price is $41 and the contract is on 100 shares. What have you committed yourself to? How much could you gain or lose?

# %% [markdown]
# Answer:
#  - To write a put is to sell a put. You have sold someone the right to sell their shares at $40 across the next 3 months. With 100 shares, this amounts to you committing to purchasing 100 shares for $4000, if exercised. If the stock stays above $40, the option is unlikely to be exercised (since you'll make a profit, not them). If the stock drops below $40, you stand to lose the difference between the strike of $40 and the current spot. Payoff = -max(0, Strike - Spot). You have unlimited risk on your downside!

# %% [markdown]
# **Q1.5** - You would like to speculate on a rise in the price of a certain stock. The current stock price is $29 and a 3-month call with a strike price of $30 costs $2.90. You have $5,800 to invest. Identify two alternative investment strategies, one in the stock and the other in an option on the stock. What are the potential gains and losses from each?

# %% [markdown]
# Answer:
#  - a) Invest directly in the stocks. Purchase 200 shares at $29 for $5800. The payoff will be: $Payoff = S_{T} - S_{0}$. If the stock increases in value, a profit will be made. If it decreases, a loss will be made.
#  - b) Invest in options in the stocks. Purchase 3-month call options with strike prices of $30 for $2.90 each. Purchase 2000 options for $5800. The payoff will be: $Payoff = max(K - S_{T}, 0) - 5,800$
#  - The options strategy will have greater upside but equally greater downside - this is due to **leverage**

# %% [markdown]
# **Q1.6** - Suppose that you own 5,000 shares worth $25 each. How can put options be used to provide you with insurance against a decline in the value of your holding over the next 4 months?

# %% [markdown]
# Answer:
#  - The asset is held, so I want to protect it and try to garuntee its price for the initial $25. I would buy 50 at-the-money 4-month put options (100 shares per option). If the share price goes up, I won't exercise and I'll decrease my asset value gain by the transaction cost of the option. If the shre price goes down, I can exercise for the original $25 per share minus the original premium cost.

# %% [markdown]
# **Q1.7** - When first issued, a stock provides funds for a company. Is the same true of a stock option? Discuss.

# %% [markdown]
# Answer:
#  - When first issue (IPO - initial public offering) the company is selling equity stakes in its company to the public for a list price. The proceeds of the selling becomes capital/equity for the company to use.
#  - An option is a derivative. It's value is derived from the underlying and other factors, it itself is not equity. It can be used to hedge, speculate or conduct arbitrage trading. It provides no value to the company itself since it is a security traded between two financial parties.

# %% [markdown]
# **Q1.8** - Explain why a futures contract can be used for either speculation or hedging.

# %% [markdown]
# Answer:
#  - A futures contract allows a party to enter into an agreement with another party (directly or via exchange/clearing house) to exchance an asset at a certain date in the future for a certain price.
#  - A speculator, who believe an asset will increase in value in time, can enter into a long future contract (agreement to buy) an asset for a price below where they speculate the future price will be. Upon receiving the underlying asset, they can sell immediately for a profit. Similarly, they can agree to sell an asset in the future for a price less than they believe the spot price will be on that day.
#  - A hedger can protect their downside through futures contracts. If looking to sell an asset in the future and believing the spot price may decrease in the meantime, they can enter into a futures contract for a price which insures today's current value.

# %% [markdown]
# **Q1.9** - Suppose that a March call option to buy a share for $50 costs $2.50 and is held until March. Under what circumstances will the holder of the option make a profit? Under what circumstances will the option be exercised> Draw a diagram illustrating how the profit from a long position in the option depends on the stock price at maturity of the option.

# %% [markdown]
# Answer:
#  - The holder of the option is the party that is 'long', e.g. they have bought the option to buy the shares at $50.
#  - The holder of this option makes a profit when the underlying exceeds $52.50 (the break even = Strike + Option Price) and will thus exercise the option
#  - The holder will exercise the option prior to expiry, should the underlying spot exceed the strike of $50. If the spot is less than the break even, exercising the option doesn't yeild a profit but reduces the $2.50 loss.
#  - Diagram:

# %%
# Import methods
import numpy as np 
import matplotlib.pyplot as plt 

# Define parameters
x_min, x_max = 40, 60
N = 101
S_t = np.linspace(x_min, x_max, N) # Underlying spot at expiry
K = 50 
tc = 2.50 
Payoff = np.maximum(0, S_t - K) - tc 

# Plot 
plt.plot(S_t, Payoff, 'k--', label='Payoff') 
plt.plot([x_min, x_max],[0, 0],'k-',label='$S_{T}$')
plt.xlim([x_min, x_max])
plt.xlabel('Stock Price, S')
plt.ylabel('Payoff')
plt.legend()
plt.show()

# %% [markdown]
# **Q1.10** - Suppose that a June put option to sell a share for $60 costs $4 and is held until June. Under what circumstances will the seller of the option (i.e. the party with the short position) make a profit? Under what circumstances will the option be exercised? Draw a diagram illustrating how the profit from a short position in the option depends on the stock price at maturity of the option.

# %% [markdown]
# Answer:
#  - If a party is short a put position, they have sold to another party the right to sell the underlying at the agreed strike and date.
#  - The short party makes a profit when the option is not exercised, thus pocketing the premium charged. For the option to not be exercised, the underlying should stay above the strike price of the option, as no counterparty would exercise the option and therefore sell their stocks for less than the higher spot.
#  - If the underlying spot price drops below the strike, the option is likely to be exercised. The seller will make a payoff of: Payoff = Option Price - max(0, Strike - Spot)
#  - Diagram:

# %%
# Calculations
K = 60 
tc = 4
x_min, x_max = 60-10, 60+10
N = 101
S_t = np.linspace(x_min, x_max, N)
Payoff = -np.maximum(0, K - S_t) + tc

# Plot 
plt.plot([x_min, x_max], [0, 0], 'k-', label='Stock')
plt.plot(S_t, Payoff, 'k--', label='Payoff') 
plt.xlim([x_min, x_max]) 
plt.xlabel('Stock Price, S') 
plt.ylabel('Payoff') 
plt.legend() 
plt.show()

# %% [markdown]
# **Q1.11** - It is May and a trader writes a September call option with a strike price of $20. The stock price is $18 and the option price is $2. Describe the trader's cash flows if the options is held until September and the stock price is $25 at that time.

# %% [markdown]
# Answer:
#  - Writing a call option means you are selling a counterparty the right to buy the underlying for the given strike and maturity.
#  - The trader will make an initial $2 in writing the option. This is received at the start and assumed invested at the risk free rate of return for the duration of the maturity.
#  - When the option is exercised in September, the trader must buy shares at $25 and sell them to the counterparty at the agreed $20. This causes a $5 loss to the trader.
#  - The trader's ending cash flow will be $2 - $5 = -$3.

# %% [markdown]
# **Q1.12** - A trader writes a December put option with a strike price of $30. The price of the option is $4. Under what circumstances does the trader make a gain?

# %% [markdown]
# Answer:
#  - The trader has sold the counterparty the right to sell their underlying for the specified strike and expiry.
#  - The trader makes an initial premium income ($4) per share and will make a gain provided the underlying spot price stays above $26 per share.

# %% [markdown]
# **Q1.13** - A company knows it is due to receive a certain amount of a foreign currency in 4 months. What type of option contract is appropriate for hedging?

# %% [markdown]
# Answer:
#  - If its receiving the currency/money is wants to ensure that the funds are worth at least as much as it is expecting. I.e. they want to protect the funds from decreasing in value.
#  - The question is slightly ambiguous in terms of if they are purchasing in 4 months or already have a futures contract in place.
#  - If they are purchasing in 4-months, they want to buy a call option for an agreement amount so that they won't spend more in 4 months for the same funds.
#  - If they are receiving based on a futures contract, they can hedge the value of their currency by buying a put option.

# %% [markdown]
# **Q1.14** - A U.S> company expects to have to pay 1 million Canadian dollars in 6 months. Explain how the exchange rate risk can be hedged using (a) a forward contract) and (b) an option.

# %% [markdown]
# Answer:
#  - (a) Enter into a forward contract for the whole amount at an agreed exchange rate and agreed settlement time. This locks in the exchange so that they isn't any downside risk. However, it also removes upside risk, meaning the firm doesn't have the option to pruchase the full amount for less if the exchange rate drops.
#  - (b) Purchase a call option (long position) in Canadian dollars. If the exchange rate increases, you can exercise the risk to purchase the amount for less. If it decreases, you can purchase for the lower spot price without exercising the option.

# %% [markdown]
# **Q1.15** - A trader enters into a short forward contract on 100 million yen. The forward exchange rate is $0.0090 per yen. How much does the trader gain or lose if the exchange rate at the end of the contract is (a) $0.0084 per yen and (b) $0.0101 per yen.

# %% [markdown]
# Answer:
#  - Short forward contract is agreement to sell 100 million yen at agreed rate
#  - Forward contract amount = $0.0090 * 1e8 = $900000
#  - (a) Current contract value = $840000. Payoff = Contract - Current = $60,000 gain
#  - (b) Current contract value = $1010000. Payoff = Contract - Current = -$110,000 loss

# %% [markdown]
# **Q1.16** - The CME Group offers a futures contract on long-term Treasury bonds. Characterize the traders likely to use this contract.

# %% [markdown]
# Answer:
#  - In order to be interested in buying a futures contract on an asset, the buyer (long party) typically has the belief that the underlying asset will increase in value by the time the futures contract is to be settled, thus meaning they purchased the asset for less than its current value. The asset can then be sold for a profit.
#
#  Answer from book: Most investors will use the contract because they want to do one of the following:
#   - Hedge an exposure to long-term interest rates
#   - Speculate on the future direction of the long-term interest rates
#   - Arbitrage between the spot and futures markets for Treasury bonds.

# %% [markdown]
# **Q1.17** - Options and futures are zero-sum games. What do you think is meant by this?

# %% [markdown]
# Answer:
#  - For every options and future sold, there is a party. This means that there is always a winner and loser to cancel each other out. For one party to make money, the counter party must lose the same amount.

# %% [markdown]
# **Q1.18** - Describe the profit from the following portfolio: a long forward contract on an asset and a long European put option on the asset with the same maturity as the forward contract and a strike price that is equal to the forward price of the asset at the time the portfolio is set up.

# %% [markdown]
# Answer:
#  - The party has bought a forward contract requiring them to purchase/exchange the underlying at the agreed maturity and forward price.
#  - The party has bought a put option, giving them the right to sell the underlying at the strike price at maturity.
#  - At maturity, the party must exchange on the forward contract, putting them in possession of the underlying, having paid the agreed forward price. They now have the right to sell the underlying at the same price they bought it for.
#  - If the asset is less than the strike, they can sell having only lost the option cost. If the asset is worth more than the strike, they can sell for a profit of Spot - Strike - transaction cost.

# %%
# Calculations
F_0 = 20 #assumed forward price
tc = 2 #assumed option cost
x_min, x_max, N = 10,30,101
S_t = np.linspace(x_min, x_max, N)
Option_payoff = np.maximum(0, F_0 - S_t) - tc
Forward_payoff = S_t - F_0
Portfolio_payoff = np.maximum(0, Forward_payoff) - tc

# Plot 
plt.plot(S_t, Option_payoff, 'k--', label='Option Payoff')
plt.plot(S_t, Forward_payoff, 'k-.', label='Forward Payoff')
plt.plot(S_t, Portfolio_payoff, 'k-', label='Payoff') 
plt.xlim([x_min, x_max]) 
plt.xlabel('Asset Price') 
plt.ylabel('Payoff')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# **Q1.19** - In the 1980s, Bankers Trust developed index currency option notes (ICONs). These were bonds in which the amount received by the holder at maturity varied with a foreign exchange rate. One example was its trade with the Long Term Credit Bank of Japan. The ICON specified that if the yen/USD exchange rate, $S_{T}$, is greater than 169 yen per dollar at maturity (in 1995), the holder of the bond receives $1,000. If it is less than 169 yen per dollar, the amount received by the holder of the bond is: \
# P = 1000 - max[0, 1000(169/S_T - 1)] \
# When the exchange rate is beow 84.5, nothing is received by the holder at maturity. Show that this ICON is a combination of a regular bond and two options.

# %% [markdown]
# Answer:
#  - Bond structure exists between 84.5 and 169 yen/USD.
#  - Below 84.5 there is nothing received and no loss. This amount to a long call option where the user will 'buy-in' to the trade/profit when the yen goes above 84.5
#  - Above 169, the profit is capped. Capping the profit is the same as selling the underlying at that price and no longer benefitting from its movements. This is a short call position.

# %%
# Calculations
x_min, x_max = 60, 200
S_t = np.linspace(x_min, x_max)
Payoff = (S_t>84.5) * (1000 - np.maximum(0, 1000*((169/S_t) - 1)))

# Plot 
plt.plot(S_t, Payoff, 'k-', label="Payoff")
plt.xlim([x_min, x_max])
plt.xlabel('Yen/USD Exchange')
plt.ylabel('Payoff')
plt.grid()
plt.show()

# %% [markdown]
# **Q1.20** - On July 1, 2021, a company enters into a forward contract to buy 10 million Japanese yen on January 1, 2022. On September 1, 2021, it enters into a forward contract to sell 10 million Japanese yen on January 1, 2022. Describe the payoff from this strategy.

# %% [markdown]
# Answer:
#  - The company has entered into a contract to buy 10 million on Jan 1, 2022 (12-month forward) and sell 10 million the same day (120-day forward). The payoff structure depends on the difference between the two strike prices of the forward contracts. Notably, it costs nothing to enter into a forward, so there shouldn't be transaction costs.
#  - If the long position has a lower strike than the short position, a profit is made. If reversed, a loss is made. The profit/loss was locked in on September 1 when the short position was taken.

# %% [markdown]
# **Q1.21** - Suppose that USD/sterling spot and forward exchange rates are as follows: \
# Spot = 1.2580, 90-day Forward = 1.2556, 180-day Forward = 1.2518 \
# What opportunities are open to an arbitrageur in the following situations? \
# (a) A 180-day Euro call option to buy £1 for $1.22 costs 2 cents \
# (b) A 90-day Euro put option to sell £1 for $1.29 costs 2 cents

# %% [markdown]
# Answer:
#  - (a): A call option means I will buy in 180-days for $1.22/£1 and it'll cost me $0.02. So my cost is $1.24/£1. The 180-day forward is worth $1.2518/£1. I can sell 180-day forward contracts at $1.2518 and purchase the call option at a cost of $1.24. This nets a garunteed return of $1.2518-$1.24 = $0.0118/£1 exchanged.
#  - (b): A put option means I will sell for $1.29 at a cost of $0.02. The cost has to come off the sale profit, giving me effective selling price of $1.27/£1. I can buy a 90-forward contract at $1.2556/£1. This nets a risk-free payoff of $1.27-£1.2556 = $0.0144/£1 exchanged.
#  The profit increases where the underlying spot move out of agreement with the forward prices (in the right direction). But a garunteed minimum is maintained.

# %% [markdown]
# **Q1.22** - A trader buys a call option with a strike price of £30 for $3. Does the trader ever exercise the option and lose money on the trade? Explain your answer.

# %% [markdown]
# Answer:
#  - Yes. Between the spot prices of $30 and $33, the trader is making a loss, however the loss is less than the current cost of the trade. This means the trader is progressively reducing the loss from $3 to $0.

# %% [markdown]
# **Q1.23** - A trader sells a put option with a strike price of $40 for $5. What is the trader's maximum gain and maximum loss? How does your answer change if it is a call option?

# %% [markdown]
# Answer:
#  - The trader makes a maximum profit of $5 per share, when the underlying stays above the strike of $40.
#  - The maximum loss is near uncapped, but since prices can't go below $0, it is $35.
#  - If they sell a call option instead, the maximum profit is the premium when the spot stays below the strike. The maximum loss is now definitely uncapped as the price of the underlying could infinitely increase forcing the trader to buy high and sell low when the option is exercised against them.

# %% [markdown]
# **Q1.24** - "Buying a put option on a stock when the stock is owned is a form of insurance." Explain this statement.

# %% [markdown]
# Answer:
#  - When you buy a put option, you are buying the right to sell for a set strike price.
#  - If you own the stock, this means you've protected the value of your stock from being worth less that the given strike price.
#  - Therefore, you've paid an insurance premium to protect your downside, while keeping your chance of an upside.

# %% [markdown]
# **Q1.25** - On May 21, 2020, as indicated in Table 1.2, the spot ask price of Apple stock is £316.50 and the ask price of a call option with a strike price of $320 and a maturity date of September is $21.70. A trader is considering two alternatives: buy 100 shares of the stock and buy 100 september call options. For each alternative, what is (a) the upfront cost, (b) the total gain if the stock price in September is $400, and (c) the total loss if the stock price is $300 in September. Assume that the option is not exercised before September and positions are unwound at option maturity.

# %% [markdown]
# Answer:
#  - Scenario: Buy 100 shares of Apple.
#     - (a) Total upfront cost = $316.50 * 100 = $31,650.00
#     - (b) Total gain = $40,000 - $31,650 = $8,350.00
#     - (c) Total loss = $31,650 - $30,000 = $1,650.00
#  - Scenario: Buy 100 call options, K = 320, cost = 21.70
#     - (a) Total upfront cost = $2,170.00
#     - (b) Total gain = (400 - 320)*100 - 2170 = 8,000 - 2,170 = $5,830
#     - (c) Total loss = $2,170

# %% [markdown]
# **Q1.26** - What is arbitrage? Explain the arbitrage opportunity when the price of a dually listed mining company stock is $50 on the NYSE and $60 on TSE. Assume that the exchange rate is such that 1 USD = 1.21 CAD. Explain what is likely to happen to prices as traders take advantage of this opportunity.

# %% [markdown]
# Answer:
#  - If the stock is listed as $50 on USD, it's CAD equivalent should be $50*1.21 = $60.50.
#  - Since it is listed at $60 CAD on TSE, traders can buy the stock on TSE and sell it on NYSE
#  - Payoff = $50 USD - ($60 CAD)/1.21 = 50 - 49.5868 = $0.4132/share.
#  - As traders exploit this arbitrage, the opportunity will close. E.g. Purchasing on the TSE will increase its price and close the margin

# %% [markdown]
# **Q1.27** - Trader A enters into a forward contract to buy an asset for $1000 in one year. Trader B buys a call option to buy the asset for $1000 in one year. The cost of the option is $100. What is the difference between the positions of the traders? Show the profit as a function of the price of the asset in one year for the two traders.

# %% [markdown]
# Answer:
# - Trader A must purchase the asset at maturity regardless of the underlying price. It is subject to both loss and gain tired directly to the asset price. There is no transaction cost to enter this trade/position.
# - Trader B must pay an initial premium for the option to purcahse the asset at maturity. The payoff is subject to the asset spot price minus the transaction cost, and the loss is capped at the transaction cost since it will not be exercised if the spot is below $100.

# %%
# Calculations
x_min, x_max, N = 800, 1200, 101
tc = 100
S_t = np.linspace(x_min, x_max, N) 
Payoff_A = S_t - 1000
Payoff_B = np.maximum(S_t - 1000,0) - tc 

# Plot 
plt.plot(S_t, Payoff_A, 'b-', label='Trader A') 
plt.plot(S_t, Payoff_B, 'r-', label='Trader B') 
plt.xlim([x_min, x_max]) 
plt.xlabel('Spot Price') 
plt.ylabel('Payoff') 
plt.grid() 
plt.legend()
plt.show()

# %% [markdown]
# **Q1.28** - In March, a US investor instructs a broker to sell one July put option contract on a stock. The stock price is $42 and the strike price is $40. The option price is $3. Explain what the investor has agreed to. Under what circumstance will the trade prove to be profitable? What are the risks?

# %% [markdown]
# Answer:
# - Selling a put option effectively requires you to buy shares from the counterparty at the agreed strike should the spot drop below the strike.
# - This means the selling initially pockets the premium of $3.
# - If the spot at expiry is between $37 and $40, the option may be exercised and reduce the premium profit. If the spot at expiry is below $37, the investor will be required to purchase the underlying from the counterparty at the agreed strike of $40, only to be able to sell it for less than $37. This results in a loss which is only bounded by the inability of the underlying to be negatively priced. The maximum loss is therefore £37.

# %% [markdown]
# **Q1.29** - A US company knows it will have to pay 3 million euros in three months. The current exchange rate is 1.15 USD/EUR. Discuss how forward and options contracts can be used by the company to hedge its exposure.

# %% [markdown]
# Answer:
# - At the current exchange rate, the company expects to pay $3.45 million USD for the 3 million euros.
# - To hedge its position, it wants to protect itself from having to pay more than 3.45, but is likely very happy to pay less.
# - A futures contract allows for the company to lock in the exchange at a future date. In exchange for locking in the rate, the company forfeits the ability to benefit from the USD becoming stronger, but protects ites from it become weaker.
# - An options contract allows for the company to pay a premium to protect its downside, but potentially capitalise on the USD becoming stronger. There is a risk that the USD doesn't weaken enough to exercise the option completely, but doesn't strength enough to eliminate the cost of the option premium. A small loss will be made in this scenario.
# - The choice between the two approaches is up to the company's appetite for risk and its outlook of the exchange rate.

# %% [markdown]
# **Q1.30** - A stock price is $29. A trader buys one call option contract on the stock with a strike price of $30 and sells a call option contract on the stock with a strike price of $32.50. The market prices of the options are $2.75 and $1.50, respectively. The options have the same maturity date. Describe the trader's position.

# %% [markdown]
# Answer:
# - The trader has purchased the right to buy the stock at $30 and sold someone the right to buy from him at $32.50. With the current stock price at $29.
# - The upfront cost is the balance of the option costs = $2.75 - $1.50 = $1.25/share.
# - This means the trader capped their upside gains in exchange for reducing the spot price required for them to make a return on their long option.

# %%
# Calculations 
x_min, x_max = 20, 40
C_1, C_2 = 2.75, 1.50 
K_1, K_2 = 30, 32.50
N = 101 
S_t = np.linspace(x_min, x_max, N) 
Short_call = np.minimum(0, K_2 - S_t) + C_2
Long_call = np.maximum(0, S_t - K_1) - C_1
Payoff = Short_call + Long_call

# Plot 
plt.plot(S_t, Short_call, 'r--', label='Short Call') 
plt.plot(S_t, Long_call, 'b--', label='Long Call') 
plt.plot(S_t, Payoff, 'k-', label='Payoff') 
plt.xlim([x_min, x_max]) 
plt.xlabel('Spot') 
plt.ylabel('Payoff') 
plt.ylim([-8, 8])
plt.grid() 
plt.legend() 
plt.show()

# %% [markdown]
# **Q1.31** - The price of gold is currently $1,200 per oounce. The forward price for delivery in 1 year is £1,300 per ouce. An arbitrageur can borrow money at 3% per annum. What should the arbitrageur do? Assume that the cost of storing gold is zero and that gold provides no income.

# %% [markdown]
# Answer:
#  - Borrow $1,200 at 3% interest to purchase gold at £1,200.
#  - Sell a forward contract for 1 year at $1,300.
#  - In one year, the trader can settle the forward for $1,300 and payback the loan for $1,236, for a profit of $64 per ounce.

# %% [markdown]
# **Q1.32** - On May 21, 2020, an investor owns 100 Apple shares. As indicated in Table 1.3, the share price is about $316 and a December put option with a strike of $290 costs $21.30. The investor is comparing two alternative to limit downside risk. The first involves buying one December put oiption ontract with a strike of $290. The second involves instructing a broker to sell the 100 shares as soon as Apple's price reaches $290. Discuss the advantages and disadvanteages of the two strategies.

# %% [markdown]
# Answer:
#  - Buying a put option allows for the investor to cap their losses for the price of a premium. This means that if the share price falls below $290, the investor can exercise the option at maturity to limit their total losses. This also reduces profits however, as should the price increase from $316, the investor has incurred the expense of the premium.
#  - Instructing the broker to sell when the stock hits a limit means that the investor will save on the expense of an option, however, they've lost optionality. The reality is that the stock price could gain again from $290 but the investor will have lost the opportunity to follow said trend as their position will have been liquidated.

# %% [markdown]
# **Q1.33** - A bond issued by Standard Oil some time ago worked as follows: The holder received no interest. At the bond's maturity the company promised to pay $1,000 plus an additional amount based on the price of oil at the time. The additional amount was equal to the product of 170 and the excess (if any) of the price of a barrel of oil at maturity over $25. The maximum additional amount paid was $2,550 (which corresponds to a price of $40 per barrel). Show tha tthe bond is a combination of a regular bond, a long position in call options on oil with a strike of $25, and a short position in call options on oil with a strike price of $40.

# %%
#Calculations  
x_min, x_max, Nx = 20, 45, 101 
S_t = np.linspace(x_min, x_max, Nx) 
K_1 = 25
K_2 = 40
Payoff = np.minimum(2550, (S_t > K_1) * np.maximum(S_t - K_1, 0) * 170) + 1000

# Plot  
plt.plot(S_t, Payoff, 'k-', label='Payoff')
plt.xlim([x_min, x_max]) 
plt.xlabel('Spot') 
plt.ylabel('Payoff') 
plt.legend() 
plt.grid()
plt.show()

# %% [markdown]
# **Q1.34** - Suppose that in the situation of Table 1.1 a corporate treasurer said: "I will have £1 million to sell in 6 months. If th exchange rate is less that 1.19, I want you to give me 1.19. If it is greater than 1.25, I will accept 1.25. If the exchange rate is between 1.19 and 1.25, I will sell the sterling for the exchange rate". How could you use options to satisfy the treasurer?

# %% [markdown]
# Answer:
# - Buy a put option for 1.19, so that you gain the right to sell for 1.19 if the exchange is below that.
# - Sell a call option for 1.25, so that a counterparty will exercise and buy my money if the exchange exceeds 1.25.
# - If the exchange does not exceed either, sell on the spot market for the given spot rate.
