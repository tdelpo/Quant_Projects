# %% [markdown]
# A set of coins consists of 98 fair coins, one double-headed coin, and one double-tailed coin. A coin is chosen at random, flipped, and it shows heads. What is the probability that the chosen coin is the double-headed one?
#
# Ans = 0.02

# %%
# No sim
