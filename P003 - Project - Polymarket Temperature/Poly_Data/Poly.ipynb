# %% [markdown]
# **Thoughts**:
# - We able to pull in current, next day, and next next day forecast probability
# - Identify spread betting opportunities:
#     - If forecast accuracy is strong, the wings of the distribution could have low risk returns
#     - If forecast accuracy is very strong on 1-2 temperatures, seek positive EV bet style
#     - Size bets with Kelly Criterion
# - Create data feed and storage for back-analysis of optimal betting framework
