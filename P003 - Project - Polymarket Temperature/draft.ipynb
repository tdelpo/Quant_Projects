# %%
import requests
import pandas as pd

url = "https://aviationweather.gov/api/data/metar"

params = {
    "ids": "EGLC",
    "format": "json",
    "hours": 24
}

df = pd.DataFrame(requests.get(url, params=params).json())

print(df)
# Out:
#    icaoId               receiptTime     obsTime                reportTime  \
# 0    EGLC  2026-06-21T20:24:14.293Z  1782073200  2026-06-21T20:20:00.000Z
# 1    EGLC  2026-06-21T19:54:07.559Z  1782071400  2026-06-21T20:00:00.000Z
# 2    EGLC  2026-06-21T19:24:21.631Z  1782069600  2026-06-21T19:20:00.000Z
# 3    EGLC  2026-06-21T18:54:11.819Z  1782067800  2026-06-21T19:00:00.000Z
# 4    EGLC  2026-06-21T18:24:31.467Z  1782066000  2026-06-21T18:20:00.000Z
# 5    EGLC  2026-06-21T17:54:17.209Z  1782064200  2026-06-21T18:00:00.000Z
# 6    EGLC  2026-06-21T17:24:17.888Z  1782062400  2026-06-21T17:20:00.000Z
# 7    EGLC  2026-06-21T16:54:16.933Z  1782060600  2026-06-21T17:00:00.000Z
# 8    EGLC  2026-06-21T16:24:16.424Z  1782058800  2026-06-21T16:20:00.000Z
# 9    EGLC  2026-06-21T15:54:20.805Z  1782057000  2026-06-21T16:00:00.000Z
# 10   EGLC  2026-06-21T15:24:30.223Z  1782055200  2026-06-21T15:20:00.000Z
# 11   EGLC  2026-06-21T14:54:12.483Z  1782053400  2026-06-21T15:00:00.000Z
# ...
